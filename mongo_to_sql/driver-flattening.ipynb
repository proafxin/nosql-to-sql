# %%
from os import (
    getcwd,
)
from os.path import (
    join,
)
from json import (
    loads,
)
from pandas import (
    DataFrame,
)

from flatten import flatten_auto

# %%
pwd = getcwd()
datadir = join(pwd, 'data/')
path = join(datadir, 'data.json')
f = open(path)
data = loads(f.read())

# %%
data
# Out:
# {'no': '',
#  'year': 1990,
#  'movies': [{'name': 'A', 'director': 'AB'},
#   {'name': 'B', 'actor': 'C'},
#   {'name': 'D', 'director': 'Director'}],
#  'extras': [{'A': {'u': 'U'}},
#   {'B': {'v': 'V'}},
#   {'A': {'u': 'W'}, 'B': {'v': 'X'}}],
#  'others': {'c': 'C', 'd': {'e': 'E'}},
#  'nothing': ''}

# %% [markdown]
# ### Data has to be either a dictionary or list of dictionary (dataframe).

# %%
result = flatten_auto(
    data,
    depth=0,
    depth_cur=0,
)

# %%
result
# Out:
#   no  year                                             movies  \
# 0     1990  [{'name': 'A', 'director': 'AB'}, {'name': 'B'...
#
#                                               extras nothing others.c  \
# 0  [{'A': {'u': 'U'}}, {'B': {'v': 'V'}}, {'A': {...                C
#
#   others.d.e
# 0          E

# %%
result = flatten_auto(
    data,
    depth=1,
    depth_cur=0,
)

# %%
result
# Out:
#    no  year nothing others.c others.d.e movies.name movies.director  \
# 0      1990                C          E           A              AB
# 1      1990                C          E           A              AB
# 2      1990                C          E           A              AB
# 3      1990                C          E           A              AB
# 4      1990                C          E           A              AB
# 5      1990                C          E           A              AB
# 6      1990                C          E           A              AB
# 7      1990                C          E           A              AB
# 8      1990                C          E           A              AB
# 9      1990                C          E           B             NaN
# 10     1990                C          E           B             NaN
# 11     1990                C          E           B             NaN
# 12     1990                C          E           B             NaN
# ...

# %%
result = flatten_auto(
    data,
    depth=2,
    depth_cur=0,
)

# %%
result
# Out:
#    no  year nothing others.c others.d.e movies.name movies.director  \
# 0      1990                C          E           A              AB
# 1      1990                C          E           A              AB
# 2      1990                C          E           A              AB
# 3      1990                C          E           A              AB
# 4      1990                C          E           A              AB
# 5      1990                C          E           A              AB
# 6      1990                C          E           A              AB
# 7      1990                C          E           A              AB
# 8      1990                C          E           A              AB
# 9      1990                C          E           B             NaN
# 10     1990                C          E           B             NaN
# 11     1990                C          E           B             NaN
# 12     1990                C          E           B             NaN
# ...
